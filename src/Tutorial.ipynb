# %%
from sogaPreprocessor import *
from producecfg import *
from libSOGA import *

# %%
compiledFile=transform2gm('../programs/SOGA/Bernoulli.soga')

# %%
cfg = produce_cfg(compiledFile)
# Out:
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1

# %%
output_dist = soga_analyze(cfg)
# Out:
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ANTLR runtime and generated code versions disagree: 4.11.1!=4.10.1
# ...

# %%
output_dist
# Out:
# Dist<['theta', 'y'],pi: [0.0005197882177909181, 0.002827563540514495, 1.008505933587566e-05, 9.351256270220498e-05, 1.007529800612435e-05, 9.361935534032585e-05, 3.836133055504316e-07, 5.9575015423504895e-06, 1.0052149451075553e-05, 9.381289313415014e-05, 3.8398120738107664e-07, 6.052565102706766e-06, 3.839729120499292e-07, 6.052450621852242e-06, 2.5049142289195405e-08, 6.383115776755346e-07, 1.001451892322211e-05, 9.418595677537882e-05, 3.8509017942610805e-07, 6.193727413606902e-06, 3.850892459997481e-07, 6.193446006358574e-06, 2.552483988632088e-08, 6.70231319415829e-07, 3.8478342024883546e-07, 6.193539999724966e-06, 2.5482430330914713e-08, 6.742026419952381e-07, 2.5497569760917906e-08, 6.739724813276529e-07, 2.5820340971828843e-09, 1.0614072514203335e-07, 9.96336346365878e-06, 9.492528666517709e-05, 3.8769243563080136e-07, 6.413676697814113e-06, 3.8770522507806384e-07, 6.413116227689387e-06, 2.6278716605884863e-08, 7.181002016411549e-07, 3.873882464224645e-07, 6.412892076081539e-0
# ...

# %%
output_dist.var_list
# Out:
# ['theta', 'y']

# %%
output_dist.gm
# Out:
# pi: [0.0005197882177909181, 0.002827563540514495, 1.008505933587566e-05, 9.351256270220498e-05, 1.007529800612435e-05, 9.361935534032585e-05, 3.836133055504316e-07, 5.9575015423504895e-06, 1.0052149451075553e-05, 9.381289313415014e-05, 3.8398120738107664e-07, 6.052565102706766e-06, 3.839729120499292e-07, 6.052450621852242e-06, 2.5049142289195405e-08, 6.383115776755346e-07, 1.001451892322211e-05, 9.418595677537882e-05, 3.8509017942610805e-07, 6.193727413606902e-06, 3.850892459997481e-07, 6.193446006358574e-06, 2.552483988632088e-08, 6.70231319415829e-07, 3.8478342024883546e-07, 6.193539999724966e-06, 2.5482430330914713e-08, 6.742026419952381e-07, 2.5497569760917906e-08, 6.739724813276529e-07, 2.5820340971828843e-09, 1.0614072514203335e-07, 9.96336346365878e-06, 9.492528666517709e-05, 3.8769243563080136e-07, 6.413676697814113e-06, 3.8770522507806384e-07, 6.413116227689387e-06, 2.6278716605884863e-08, 7.181002016411549e-07, 3.873882464224645e-07, 6.412892076081539e-06, 2.622979129720265
# ...

# %%
output_dist.gm.n_comp()
# Out:
# 1964

# %%
output_dist.gm.mean()
# Out:
# array([0.25695467, 1.        ])

# %%
output_dist.gm.cov()
# Out:
# array([[ 1.26503562e-02, -4.99600361e-16],
#        [-4.99600361e-16, -1.99840144e-15]])

# %%
import matplotlib.pyplot as plt

x = np.linspace(0,1,100)
y = [output_dist.gm.pdf([xi,1.0]) for xi in x]

plt.plot(x,y)
